# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#carregar os arquivos
df = pd.read_csv(r'C:\Dev\inteligencia-artificial\telco.csv',sep=',')

# %%
#mostrar os 5 primeiros registros
#df.head()

# %%
#mostrar 5 ultimos registros
#df.tail()

# %%
# mostrar a estrutura / schema dos dados
#df.info()

# %%
#transformar o totalcharges de string para floalt, como tem espaço apresentou erro 
#df.TotalCharges =df.totalcharges.astype(float)

# %%
#transformar o totalcharges de string para floalt, como tem espaço apresentou erro 
#df.TotalCharges =pd.to_numeric(df.totalcharges)

# %%
#tranformar coluna tatalchager de string para float abordagem to_mumeric com coerce
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
#mostrar a estrutura modificado Total change como float
#após a transformação da coluna 11 registro foi transformado como nullo
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7043 non-null   int64
#  1   customerID        7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   object
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
#Renomear coluna
# utilizando remane dicionario
df.rename(columns={'SeniorCitizen':'Above65yo'})
# Out:
#       Unnamed: 0  customerID  gender Above65yo Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female        No     Yes         No       1
# 1              1  5575-GNVDE    Male        No      No         No      34
# 2              2  3668-QPYBK    Male        No      No         No       2
# 3              3  7795-CFOCW    Male        No      No         No      45
# 4              4  9237-HQITU  Female        No      No         No       2
# ...          ...         ...     ...       ...     ...        ...     ...
# 7038        7038  6840-RESVB    Male        No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female        No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female        No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male       Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male        No      No         No      66
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# ...

# %%
#Renomear coluna
# aplicando o inplace para gravar 
df.rename(columns={'SeniorCitizen':'Above65yo'},inplace=True)

# %%
#contar registro
len(df.customerID)
# Out:
# 7043

# %%
# quantos dados tem daddos ausentes 
df.isna().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
#qualquer valor null na linha do datafreme
df[df.isna().any(axis=1)]
# Out:
#       Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 488          488  4472-LVYGI  Female            No     Yes        Yes       0
# 753          753  3115-CZMZD    Male            No      No        Yes       0
# 936          936  5709-LVOEQ  Female            No     Yes        Yes       0
# 1082        1082  4367-NUYAO    Male            No     Yes        Yes       0
# 1340        1340  1371-DWPAZ  Female            No     Yes        Yes       0
# 3331        3331  7644-OMVMY    Male            No     Yes        Yes       0
# 3826        3826  3213-VVOLG    Male            No     Yes        Yes       0
# 4380        4380  2520-SGTTA  Female            No     Yes        Yes       0
# 5218        5218  2923-ARZLG    Male            No     Yes        Yes       0
# 6670        6670  4075-WKNIU  Female            No     Yes        Yes       0
# 6754        6754  2775-SEFEE    Male            No      No        Yes       0
#
# ...

# %%
#qualquer valor null na coluna do datafreme
df.isna().any(axis=0).sum()
# Out:
# np.int64(1)

# %%
###remover colunas com o valor ausente
df.drop(columns=['TotalCharges'],axis=1)
# Out:
#       Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female            No     Yes         No       1
# 1              1  5575-GNVDE    Male            No      No         No      34
# 2              2  3668-QPYBK    Male            No      No         No       2
# 3              3  7795-CFOCW    Male            No      No         No      45
# 4              4  9237-HQITU  Female            No      No         No       2
# ...          ...         ...     ...           ...     ...        ...     ...
# 7038        7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male            No      No         No      66
#
# ...

# %%
#remover somente os valores da colunas 

df.dropna(axis=1)
# Out:
#       Unnamed: 0  customerID  gender Above65yo Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female        No     Yes         No       1
# 1              1  5575-GNVDE    Male        No      No         No      34
# 2              2  3668-QPYBK    Male        No      No         No       2
# 3              3  7795-CFOCW    Male        No      No         No      45
# 4              4  9237-HQITU  Female        No      No         No       2
# ...          ...         ...     ...       ...     ...        ...     ...
# 7038        7038  6840-RESVB    Male        No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female        No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female        No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male       Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male        No      No         No      66
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
#remover coluna onde todos os dados são ausente
df.dropna(axis=1, how='all')
# Out:
#       Unnamed: 0  customerID  gender Above65yo Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female        No     Yes         No       1
# 1              1  5575-GNVDE    Male        No      No         No      34
# 2              2  3668-QPYBK    Male        No      No         No       2
# 3              3  7795-CFOCW    Male        No      No         No      45
# 4              4  9237-HQITU  Female        No      No         No       2
# ...          ...         ...     ...       ...     ...        ...     ...
# 7038        7038  6840-RESVB    Male        No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female        No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female        No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male       Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male        No      No         No      66
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# ...

# %%
#remover as linhas ausentes..

df.dropna(axis=0)
# Out:
#       Unnamed: 0  customerID  gender Above65yo Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female        No     Yes         No       1
# 1              1  5575-GNVDE    Male        No      No         No      34
# 2              2  3668-QPYBK    Male        No      No         No       2
# 3              3  7795-CFOCW    Male        No      No         No      45
# 4              4  9237-HQITU  Female        No      No         No       2
# ...          ...         ...     ...       ...     ...        ...     ...
# 7038        7038  6840-RESVB    Male        No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female        No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female        No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male       Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male        No      No         No      66
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# ...

# %%
#remover onde todas as linhas ausentes..

df.dropna(axis=0,how='all')
# Out:
#       Unnamed: 0  customerID  gender Above65yo Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female        No     Yes         No       1
# 1              1  5575-GNVDE    Male        No      No         No      34
# 2              2  3668-QPYBK    Male        No      No         No       2
# 3              3  7795-CFOCW    Male        No      No         No      45
# 4              4  9237-HQITU  Female        No      No         No       2
# ...          ...         ...     ...       ...     ...        ...     ...
# 7038        7038  6840-RESVB    Male        No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female        No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female        No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male       Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male        No      No         No      66
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# ...

# %% [markdown]
# #Imputar o valor onde for auzente

# %%
# fillna coloca os dados nos parentes no campo
df.fillna(0)

# %%
# Preenche o valores padrões conforme a coluna 

df.fillna(value={'TotalCharges':0})
# Out:
#       Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female            No     Yes         No       1
# 1              1  5575-GNVDE    Male            No      No         No      34
# 2              2  3668-QPYBK    Male            No      No         No       2
# 3              3  7795-CFOCW    Male            No      No         No      45
# 4              4  9237-HQITU  Female            No      No         No       2
# ...          ...         ...     ...           ...     ...        ...     ...
# 7038        7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male            No      No         No      66
#
# ...

# %%
#Preencher todos os valores auzente de uma columa com a media .
media= df.TotalCharges.mean()

# %%
#Aplica o valor medido no campo vazio
df.fillna(value={'TotalCharges':media})
# Out:
#       Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female            No     Yes         No       1
# 1              1  5575-GNVDE    Male            No      No         No      34
# 2              2  3668-QPYBK    Male            No      No         No       2
# 3              3  7795-CFOCW    Male            No      No         No      45
# 4              4  9237-HQITU  Female            No      No         No       2
# ...          ...         ...     ...           ...     ...        ...     ...
# 7038        7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039        7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040        7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041        7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042        7042  3186-AJIEK    Male            No      No         No      66
#
# ...
